# %% [markdown]
# # Waze Project

# %% [markdown]
# **Group Members**
# 1. Suyeon Han
# 2. Walter Oyugi
# 3. Geofrey Kipsang
# 4. Adeline Makokha

# %% [markdown]
# # Introduction
# Waze is a community-driven navigation app that provides real-time traffic information and route guidance. Developed by an Israeli company, Waze Mobile, it was acquired by Google in 2013. Unlike traditional GPS navigation systems, Waze relies on user-generated data to offer live updates on traffic conditions, road hazards, accidents, and other relevant information.
#
# Key Features of Waze:
# Real-Time Traffic Updates: Waze users (also known as Wazers) can report traffic jams, accidents, speed traps, and road closures, allowing the app to provide real-time updates and suggest alternate routes.
# Community-Driven: The power of Waze lies in its active community of users who contribute information to keep maps accurate and up-to-date.
# Navigation Assistance: Waze offers turn-by-turn voice navigation, lane guidance, and estimated time of arrival based on current traffic conditions.
# Alerts and Notifications: Users receive alerts about upcoming road conditions, police activity, and traffic cameras.
# Integration with Other Services: Waze integrates with various services, including music streaming apps and calendar events, to enhance the driving experience.
# Waze has become a popular tool for drivers looking to avoid traffic and reach their destinations more efficiently. Its reliance on community input makes it a dynamic and constantly evolving platform.

# %% [markdown]
# # Task 1: Read data from csv file into a pandas dataframe
# * You are given a dataset file called waze.upload it and read it

# %% [markdown]
# # 1a: Import statements
# *
# Import pandas.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1b: Read in the first file
#
# **Use the pd.read_csv() function to read in the data from the waze dataset with the most observations.
#  The file is called waze_dataset.csv.
#  Assign the resulting dataframe to a variable name df.**
#
# Use the head() method on df dataframe to inspect the first five rows.

# %%
df = pd.read_csv(r'C:\Users\walte\Downloads\waze_dataset.csv')
df
# Out:
#           ID     label  sessions  drives  total_sessions  \
# 0          0  retained       283     226      296.748273
# 1          1  retained       133     107      326.896596
# 2          2  retained       114      95      135.522926
# 3          3  retained        49      40       67.589221
# 4          4  retained        84      68      168.247020
# ...      ...       ...       ...     ...             ...
# 14994  14994  retained        60      55      207.875622
# 14995  14995  retained        42      35      187.670313
# 14996  14996  retained       273     219      422.017241
# 14997  14997   churned       149     120      180.524184
# 14998  14998  retained        73      58      353.419797
#
#        n_days_after_onboarding  total_navigations_fav1  \
# 0                         2276                     208
# 1                         1225                      19
# 2                         2651                       0
# ...

# %%
df.head()
# Out:
#    ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0   0  retained       283     226      296.748273                     2276
# 1   1  retained       133     107      326.896596                     1225
# 2   2  retained       114      95      135.522926                     2651
# 3   3  retained        49      40       67.589221                       15
# 4   4  retained        84      68      168.247020                     1562
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# 1                      19                      64      13715.920550
# 2                       0                       0       3059.148818
# 3                     322                       7        913.591123
# 4                     166                       5       3950.202008
#
#    duration_minutes_drives  activity_days  driving_days   device
# ...

# %%
df.head(5)
# Out:
#    ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0   0  retained       283     226      296.748273                     2276
# 1   1  retained       133     107      326.896596                     1225
# 2   2  retained       114      95      135.522926                     2651
# 3   3  retained        49      40       67.589221                       15
# 4   4  retained        84      68      168.247020                     1562
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# 1                      19                      64      13715.920550
# 2                       0                       0       3059.148818
# 3                     322                       7        913.591123
# 4                     166                       5       3950.202008
#
#    duration_minutes_drives  activity_days  driving_days   device
# ...

# %% [markdown]
# # Task 2: Summary information
# *Now that you have a dataframe with the waze data for the individuals, get some high-level summary information about it.*

# %% [markdown]
# ## 2a: Metadata
# * Use a DataFrame method to examine the number of rows and columns, the column names, the data type contained in each column, the number of non-null values in each column, and the amount of memory the dataframe uses.

# %%
#data type contain in each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       14999 non-null  int64
#  1   label                    14299 non-null  object
#  2   sessions                 14999 non-null  int64
#  3   drives                   14999 non-null  int64
#  4   total_sessions           14999 non-null  float64
#  5   n_days_after_onboarding  14999 non-null  int64
#  6   total_navigations_fav1   14999 non-null  int64
#  7   total_navigations_fav2   14999 non-null  int64
#  8   driven_km_drives         14999 non-null  float64
#  9   duration_minutes_drives  14999 non-null  float64
#  10  activity_days            14999 non-null  int64
#  11  driving_days             14999 non-null  int64
#  12  device                   14999 non-null  object
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1.5+ MB

# %%
#examine the number of rows and columns
df.shape
# Out:
# (14999, 13)

# %%
3#columns in the dataset
df.columns
# Out:
# Index(['ID', 'label', 'sessions', 'drives', 'total_sessions',
#        'n_days_after_onboarding', 'total_navigations_fav1',
#        'total_navigations_fav2', 'driven_km_drives', 'duration_minutes_drives',
#        'activity_days', 'driving_days', 'device'],
#       dtype='object')

# %%
#checking for the missing values
df.isnull().sum()
# Out:
# ID                           0
# label                      700
# sessions                     0
# drives                       0
# total_sessions               0
# n_days_after_onboarding      0
# total_navigations_fav1       0
# total_navigations_fav2       0
# driven_km_drives             0
# duration_minutes_drives      0
# activity_days                0
# driving_days                 0
# device                       0
# dtype: int64

# %% [markdown]
# There are missing values in column label

# %%
# Drop rows with missing values in the 'label' column
df = df.dropna(subset=['label'])

# Verify that there are no more missing values in the 'label' column
missing_values_after_drop = df.isnull().sum()
print("\nMissing values after dropping rows with missing 'label':\n", missing_values_after_drop)
# Out:
# Missing values after dropping rows with missing 'label':
#  ID                         0
# label                      0
# sessions                   0
# drives                     0
# total_sessions             0
# n_days_after_onboarding    0
# total_navigations_fav1     0
# total_navigations_fav2     0
# driven_km_drives           0
# duration_minutes_drives    0
# activity_days              0
# driving_days               0
# device                     0
# dtype: int64

# %% [markdown]
# ## 2b: Summary statistics
# * Examine the summary statistics of the dataframe's numeric columns. The output should be a table that includes row count, mean, standard deviation, min, max, and quartile values.

# %%
df.describe().T
# Out:
#                            count         mean          std        min  \
# ID                       14299.0  7503.573117  4331.207621   0.000000
# sessions                 14299.0    80.623820    80.736502   0.000000
# drives                   14299.0    67.255822    65.947295   0.000000
# total_sessions           14299.0   189.547409   136.189764   0.220211
# n_days_after_onboarding  14299.0  1751.822505  1008.663834   4.000000
# total_navigations_fav1   14299.0   121.747395   147.713428   0.000000
# total_navigations_fav2   14299.0    29.638296    45.350890   0.000000
# driven_km_drives         14299.0  4044.401535  2504.977970  60.441250
# duration_minutes_drives  14299.0  1864.199794  1448.005047  18.282082
# activity_days            14299.0    15.544653     9.016088   0.000000
# driving_days             14299.0    12.182530     7.833835   0.000000
#
#                                  25%          50%           75%           max
# ...

# %% [markdown]
# ### observation
# The data for these variables show high variability and right-skewness, especially in 'sessions', 'drives', and 'total_sessions', suggesting that while most users have a moderate number of sessions and drives, there are a few with significantly higher values.
# This may warrant further investigation into these outliers to understand the reasons for such high values

# %% [markdown]
# # Task 3: Explore your data¶
# Practice exploring your data..

# %% [markdown]
# ## 3a: Rows per device
# Select the device column and use the value_counts() method on it to check how many rows there are for each device in the dataframe

# %%
#Unique rows for device
df['device'].value_counts()
# Out:
# device
# iPhone     9225
# Android    5074
# Name: count, dtype: int64

# %%
#unique rows for label
df['label'].value_counts()
# Out:
# label
# retained    11763
# churned      2536
# Name: count, dtype: int64

# %% [markdown]
# ## Sort by sessions
# 1. Create a new dataframe called df_sorted by using the sort_values() method on the df dataframe.
# 2.
# The new dataframe should contain the data sorted bysessionsI
# 3.  beginning with the rows with the highestsessionI values.  d.

# %%
df_sorted = df.sort_values(by='sessions', ascending=False)



df_sorted.head(10)
# Out:
#           ID     label  sessions  drives  total_sessions  \
# 12446  12446   churned       743     596      839.987478
# 12646  12646  retained       725     582      737.475335
# 8234    8234  retained       693     563      871.394467
# 8358    8358   churned       690     552      728.187235
# 5407    5407  retained       671     538      888.529872
# 5895    5895  retained       671     546      839.283344
# 13071  13071  retained       657     529      661.914877
# 12059  12059   churned       627     506      628.840276
# 5316    5316  retained       625     501      722.190027
# 9771    9771  retained       608     514      771.743616
#
#        n_days_after_onboarding  total_navigations_fav1  \
# 12446                      360                       0
# 12646                     2098                    1077
# 8234                      1968                     311
# 8358                      3138                     499
# 5407                      1958                     137
# ...

# %%
df[['sessions']].min()
# Out:
# sessions    0
# dtype: int64

# %%
df[['sessions']].max()
# Out:
# sessions    743
# dtype: int64

# %%
df[['sessions']].mean()
# Out:
# sessions    80.62382
# dtype: float64

# %% [markdown]
# ### 3c: Use iloc to select rows
# Use iloc to select the two rows at indices 10 and 11 of the df_sorted dataframe

# %%
df.iloc[[10,11]]
# Out:
#     ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 10  10  retained        23      20      117.225772                     1946
# 11  11  retained       125     100      357.179031                      487
#
#     total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 10                       0                      36       8554.914440
# 11                       3                       7       2284.819767
#
#     duration_minutes_drives  activity_days  driving_days  device
# 10              5352.567720              9             9  iPhone
# 11              1034.651333              1             1  iPhone

# %% [markdown]
# Use iloc to select the two rows at indices  upto 11 of the df_sorted dataframe

# %%
df.iloc[:11]
# Out:
#     ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0    0  retained       283     226      296.748273                     2276
# 1    1  retained       133     107      326.896596                     1225
# 2    2  retained       114      95      135.522926                     2651
# 3    3  retained        49      40       67.589221                       15
# 4    4  retained        84      68      168.247020                     1562
# 5    5  retained       113     103      279.544437                     2637
# 6    6  retained         3       2      236.725314                      360
# 7    7  retained        39      35      176.072845                     2999
# 8    8  retained        57      46      183.532018                      424
# 9    9   churned        84      68      244.802115                     2997
# 10  10  retained        23      20      117.225772                     1946
#
# ...

# %% [markdown]
# ### 3d: Use loc to select rows

# %%
df.loc[0:10,['label','total_sessions']]
# Out:
#        label  total_sessions
# 0   retained      296.748273
# 1   retained      326.896596
# 2   retained      135.522926
# 3   retained       67.589221
# 4   retained      168.247020
# 5   retained      279.544437
# 6   retained      236.725314
# 7   retained      176.072845
# 8   retained      183.532018
# 9    churned      244.802115
# 10  retained      117.225772

# %%
df.loc[0:10,['drives', 'device']]
# Out:
#     drives   device
# 0      226  Android
# 1      107   iPhone
# 2       95  Android
# 3       40   iPhone
# 4       68  Android
# 5      103   iPhone
# 6        2   iPhone
# 7       35   iPhone
# 8       46  Android
# 9       68   iPhone
# 10      20   iPhone

# %% [markdown]
# Task 4: Examine the data

# %% [markdown]
# Basic Boolean masking

# %%
ca_df = df_sorted[df_sorted['device'] =='Android']

ca_df.head(5)
# Out:
#           ID     label  sessions  drives  total_sessions  \
# 12646  12646  retained       725     582      737.475335
# 8358    8358   churned       690     552      728.187235
# 13071  13071  retained       657     529      661.914877
# 9797    9797  retained       590     472      677.359139
# 14369  14369  retained       540     433      690.579038
#
#        n_days_after_onboarding  total_navigations_fav1  \
# 12646                     2098                    1077
# 8358                      3138                     499
# 13071                     2939                     334
# 9797                      3285                      29
# 14369                     2126                      94
#
#        total_navigations_fav2  driven_km_drives  duration_minutes_drives  \
# 12646                      55       4743.892888              2477.289593
# 8358                       52       9048.490104              2073.484493
# ...

# %%
df_sorted.columns
# Out:
# Index(['ID', 'label', 'sessions', 'drives', 'total_sessions',
#        'n_days_after_onboarding', 'total_navigations_fav1',
#        'total_navigations_fav2', 'driven_km_drives', 'duration_minutes_drives',
#        'activity_days', 'driving_days', 'device'],
#       dtype='object')

# %%
ca_df2 = df_sorted[df_sorted['drives'] <=200]

ca_df2.head(5)
# Out:
#           ID     label  sessions  drives  total_sessions  \
# 6994    6994  retained       250     200      382.509057
# 8152    8152  retained       250     200      257.648266
# 14141  14141  retained       249     200      249.371372
# 622      622   churned       249     200      284.142732
# 1453    1453  retained       249     199      464.256245
#
#        n_days_after_onboarding  total_navigations_fav1  \
# 6994                      3104                      12
# 8152                      3259                     199
# 14141                       23                     137
# 622                       2153                      73
# 1453                       274                     244
#
#        total_navigations_fav2  driven_km_drives  duration_minutes_drives  \
# 6994                       66       3915.872193               647.641254
# 8152                        0       4072.065322              1718.003268
# ...

# %% [markdown]
# 4b. Validate ca dataframe

# %%
ca_df.shape
# Out:
# (5074, 13)

# %% [markdown]
# 4C: Rows per device

# %%
device_counts = ca_df['device'].value_counts()
print(device_counts)
# Out:
# device
# Android    5074
# Name: count, dtype: int64

# %% [markdown]
#  # Visualize the Data

# %%
# Set plot style
sns.set(style="whitegrid")

# Plot the distribution of the label (retention status)
plt.figure(figsize=(10, 4))
sns.countplot(x='label', data=df)
plt.title('Distribution of User Retention Status')
plt.xlabel('Retention Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Observation
#
# Many User continued using Waze app as opposed to those who churned.

# %%
# Plot the distribution of the number of sessions
plt.figure(figsize=(8, 6))
sns.histplot(df['sessions'], bins=30, kde=True)
plt.title('Distribution of Number of Sessions')
plt.xlabel('Number of Sessions')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\walte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot the distribution of the number of drives
plt.figure(figsize=(8, 6))
sns.histplot(df['drives'], bins=30, kde=True)
plt.title('Distribution of Number of Drives')
plt.xlabel('Number of Drives')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\walte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot the distribution of total kilometers driven
plt.figure(figsize=(8, 6))
sns.histplot(df['driven_km_drives'], bins=30, kde=True)
plt.title('Distribution of Total Kilometers Driven')
plt.xlabel('Total Kilometers Driven')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\walte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Columns for which we want histograms
columns_to_plot = [
    'sessions', 'drives', 'total_sessions', 'n_days_after_onboarding', 
    'total_navigations_fav1', 'total_navigations_fav2', 'driven_km_drives', 
    'duration_minutes_drives', 'activity_days', 'driving_days'
]

# Plotting histograms
for column in columns_to_plot:
    plt.figure()
    df[column].hist(bins=10, edgecolor='blue')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(False)
    plt.show()

# %% [markdown]
# # Bivarative analysis

# %% [markdown]
# ** Plot Scatter Plots**:
# You can use Seaborn's scatterplot function to create scatter plots for pairs of columns.

# %%
sns.scatterplot(x='sessions', y='drives', data=df)
plt.title('Sessions vs Drives')
plt.show()

# %% [markdown]
# ## Feature Importance (for models)
# If you're using machine learning models, plotting feature importance can help you understand which features are most relevant to your target variable.

# %% [markdown]
#  ### Label Encoding:
# This approach converts each unique string label into a corresponding numeric value. It’s suitable if the label column has a small number of unique values.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Encode the 'label' and 'device' columns
le_label = LabelEncoder()
df['label'] = le_label.fit_transform(df['label'])

le_device = LabelEncoder()
df['device'] = le_device.fit_transform(df['device'])

# Initialize and fit the Random Forest model
model = RandomForestRegressor()
model.fit(df.drop(columns=['label']), df['label'])

# Plot feature importances
feature_importances = pd.Series(model.feature_importances_, index=df.drop(columns=['label']).columns)
feature_importances.plot(kind='barh')
plt.title('Feature Importance')
plt.show()
# Out:
# C:\Users\walte\AppData\Local\Temp\ipykernel_6548\3968790170.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = le_label.fit_transform(df['label'])
# C:\Users\walte\AppData\Local\Temp\ipykernel_6548\3968790170.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['device'] = le_device.fit_transform(df['device'])
